# %%
import cv2
import os
import json
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import urllib.request as urllib2

# %%
def getmin(p1,p2,p3,p4):
    minx =  min(p1[0],p2[0],p3[0],p4[0])
    miny =  min(p1[1],p2[1],p3[1],p4[1])
    return(minx,miny)

# %%
def getmax(p1,p2,p3,p4):
    maxx =  max(p1[0],p2[0],p3[0],p4[0])
    maxy =  max(p1[1],p2[1],p3[1],p4[1])
    return(maxx,maxy)

# %%
def saveparkingspace(newimg,spot):
    dirname = 'Spots'
    resizeimage = cv2.resize(spot,(50,70)) #resizes image to 50 x 70
    cv2.imwrite(os.path.join(dirname, newimg + '.jpg'), resizeimage)

# %%
def maskimage(img, topleft,topright,botright,botleft):
    mask = np.zeros(img.shape, dtype=np.uint8)
    roi_corners = np.array([[topleft, topright, botright,botleft]], dtype=np.int32)  # fill the ROI so it doesn't get wiped out when the mask is applied
    channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
    ignore_mask_color = (255,)*channel_count
    cv2.fillPoly(mask, roi_corners, ignore_mask_color)
    masked_image = cv2.bitwise_and(img, mask)  # apply the mask
    return(masked_image)

# %%
def average(image,index):
    sum = 0
    count = 0
    for row in image:
        for col in row:
            if col[index] !=0:
                sum += col[index]
                count = count+1
                
    return float(sum) / count

# %%
def countwhite(image):
    im=Image.open( "canny edges/"+ parkingspacelocation +"Edge.bmp" )
    width,height = im.size
    actualpixel = width * height #how many pixels in the entire image?
    count = 0
    for row in image:
        for col in row:
            if col == 255:
                count = count + 1
    ratioofwhitepixels = float(actualpixel) / count
    print ("Number of pixels in image: " ,actualpixel)
    print ("Ratio of white to image: " ,ratioofwhitepixels)
    return count,ratioofwhitepixels

# %%
def averagecolors(image):
    avg = [average(image,0) , average(image,1) , average(image, 2)]
    return (avg)

# %%
def cannyedgedetection(spotforcanny):
    sigma=0.33
    v = np.median(spotforcanny)

    lower = int(max(0, (1.0 - sigma) * v)) #calulates the lower bound
    upper = int(min(255, (1.0 + sigma) * v)) #calucates the upper bound

    edges = cv2.Canny(spotforcanny,lower,upper) #returns and iamge map

    white = countwhite(edges) #recieves a touple (num whitepixels,ratio of whitepixels to whole image)

    dirname = 'canny edges\\'
    cv2.imwrite(dirname+parkingspacelocation+'Edge.bmp', edges)
    return white

# %%
def withinange(avg1, avg2):
    range = 0.1
    blue_diff = abs(avg1[0]-avg2[0])
    green_diff = abs(avg1[1]-avg2[1])
    red_diff = abs(avg1[2]-avg2[2])
    avg_diff = (blue_diff + green_diff + red_diff)/3
    grades = [blue_diff/255.0, green_diff/255.0, red_diff/255.0]
    #print grades
    for grade in grades:
        if grade > range:
            return False
    
    #if grades[0] > range or grades[1] > range or green_diff > range:
    #    return False
    return True

# %%
def boxemup(image,topleft,topright,botright,botleft, color):
    line_sz = 2
    diff = 5
    cv2.line(image,(topleft[0] +diff,topleft[1]),(topright[0] -diff,topright[1]),color, line_sz)#1 -> 2
    cv2.line(image,(topleft[0] +diff,topleft[1]),(botleft[0] +diff ,botleft[1]),color, line_sz) #1 -> 3
    cv2.line(image,(topright[0] -diff ,topright[1]),(botright[0] - diff,botright[1]),color, line_sz) #2 -> 4
    cv2.line(image,(botleft[0] +diff,botleft[1]),(botright[0] -diff ,botright[1]),color, line_sz) #3 -> 4
    return image

# %%
def drawBoundBox(img, color):
    line_size = 5
    #top horizontal line
    cv2.line(img, (0, 0), (len(img[0]), 0), color, line_size) 
    #left vertical line
    cv2.line(img, (0, 0), (0, len(img)), color, line_size)
    #bottom horizontal line
    cv2.line(img, (0, len(img)), (len(img[0]), len(img)), color, line_size)
    #right vertical line
    cv2.line(img, (len(img[0]), 0), (len(img[0]), len(img)), color, line_size)

# %%
def saveImgUrl(url, file_name):
    u = urllib2.urlopen(url)
    infile = open(file_name, 'wb')
    meta = u.info()
    file_size = int(meta.get_all("Content-Length")[0])
    #file_size = int(meta.getheaders("Content-Length")[0])
    print ("Downloading: %s Bytes: %s" % (file_name, file_size))

    file_size_dl = 0
    block_sz = 8192
    while True:
        buffer = u.read(block_sz)
        if not buffer:
            break
        file_size_dl += len(buffer)
        infile.write(buffer)
        status = r"%10d  [%3.2f%%]" % (file_size_dl, file_size_dl * 100. / file_size)
    status = status + chr(8)*(len(status)+1)
    print (status,infile.close())

with open('UFPR05_105.json') as data_file: #Pick the JSON that defines the parking lot you are working with
    lot_data = json.load(data_file)

with open('UFPR05_emptyData.json') as emptyLotFile: #Use the JSON that contains information about the parking lot when empty
    emptyLot_data = json.load(emptyLotFile)
red_color = (0,0,255) #Globaly defines the color red
green_color = (0,255,0) #Globaly defines the color green
if __name__ == "__main__":

    lot_shots = lot_data['data']['snapshots'] #Images of Parking-Lot
    lot_coords = lot_data['data']['coords'] #coordinates of spots in the  parking-lot

    numImg = 9 #how many images do you want to run over?

    nonchangenumImg = numImg #saves the number of images being used into a static varible
    addup = 0

    sumoverallaverage = 0 #to calculate average correctness of all images ran

#-------------------(SUBJECT TO CHANGE)--------------------------
    numwhiteratiothreshold = 10 #threshold for numwhiteratio algorithm
    numwhiteratiothresholdstart = numwhiteratiothreshold #where to start the threshold
    numwhiteratiothresholdend = 17 #where to end the threshold
    medianthreshold = 70
    whitediffernecethreshold = 90
#-------------------(SUBJECT TO CHANGE)--------------------------

    for img in lot_shots: #loop through the Parking-Lot images
        if numImg < 1 :
            break #Breaks out of the for-loop if there are no more parking lot images
        
        numImg = numImg - 1 #decrement the number images left

#-----------Calls SaveImgUrl Fuction -------------------
        url = img[1]['img'] #Parking-Lot image's URL
        img_name = img[0]+".jpg" #Gives the Parking-Lot image a name
        saveImgUrl(url, "Origin_Images\\"+img_name) 

        image = cv2.imread('Origin_Images\\' + img_name) #reads the image that was just saved
        
        spotColors = [] #Used to save the color for each spot

#----------FOR CALCULATING PERCENT OF CORRECTNESS---------------
        correctspots = 0 #Used to hold how many spots are taken in the Parking-Lot
        percentcorrect = 0 #Used to hold the value of how correct we we were

        for parkingspot in lot_coords: #loops through the Parking-Lot for each individual spot
            decidedfullorempty = 0 #Used to hold the value (0 or 1) 1 for taken  0 for empty
            
            parkingspacelocation = "Space_#_" + str(parkingspot[0]) #Parking space location in the Parking-Lot

#------------------- GETS THE COORDINATES FOR THE SPOT BEING PROCESSED ------------
            topleft = (int(parkingspot[1][3]['x']),int(parkingspot[1][3]['y'])) 
            topright = (int(parkingspot[1][2]['x']),int(parkingspot[1][2]['y']))        
            botleft = (int(parkingspot[1][0]['x']),int(parkingspot[1][0]['y']))
            botright= (int(parkingspot[1][1]['x']),int(parkingspot[1][1]['y']))

#------------------- CODE THAT APPLYS MASK TO PARKING SPACE -----------------------
            masked_image = maskimage(image,topleft,topright,botright,botleft)
            minpoint = getmin(topleft,topright,botleft,botright)
            maxpoint = getmax(topleft,topright,botleft,botright)
            maskedparkingspace = masked_image[minpoint[1]:maxpoint[1], minpoint[0]:maxpoint[0]]

            denoise = cv2.fastNlMeansDenoisingColored(maskedparkingspace,None,20,21,7,31) #gets rid of image noise
            print(parkingspacelocation)
            #print('Gavg',gray_spot_avg)
            avg = averagecolors(denoise) #gets the average of [R,G,B]
            #print('Cavg',avg)
            colorResult = [withinange(emptyLot_data['spots'][parkingspot[0]-1][1], avg)]


            gray_image = cv2.cvtColor(denoise, cv2.COLOR_BGR2GRAY) #convert the denoise'd image to grayscale
            blur = cv2.GaussianBlur(gray_image,(5,5),0) #blur the image

            numberofwhite = cannyedgedetection(blur) #Calls cannyedgedectection funcion, and recives a touple

            whitediffromempty = numberofwhite[0] - emptyLot_data['spots'][parkingspot[0]-1][2] #Differnce of number of white pixels to the spot and it's empty counterpart

            print ("Diff of whitepixels: ", whitediffromempty)
            median = np.median(blur) #gets the median of the blurred image
            print ("Median: " , median)


#-------------BELOW IS WHERE WE APPLY THE ALGORITHMS TO DIFFERENT THRESHOLDS----------------
            if median < medianthreshold: #if yes then the spot is taken
                 drawBoundBox(maskedparkingspace, red_color)
                 spotColors.append([topleft, topright, botleft, botright, red_color])
                 decidedfullorempty = 1
            elif numberofwhite[1] <= numwhiteratiothreshold: #if yes then the spot is taken
                 drawBoundBox(maskedparkingspace, red_color)
                 spotColors.append([topleft, topright, botleft, botright, red_color])
                 decidedfullorempty = 1
            elif whitediffromempty > whitediffernecethreshold: #if yes then the spot is taken
                drawBoundBox(maskedparkingspace, red_color)
                spotColors.append([topleft, topright, botleft, botright, red_color])
                decidedfullorempty = 1
            else:
                drawBoundBox(maskedparkingspace, green_color)
                spotColors.append([topleft, topright, botleft, botright, green_color])
                decidedfullorempty = 0


            if (int(lot_data['data']['snapshots'][addup][1]["lotSnapshot"][str(parkingspot[0])]) == 0):
                print('Actual result from Json: OPEN') #Uses JSON the print the actual status of the spot
            else:  
                print('Actual result from Json: TAKEN') #Uses JSON the print the actual status of the spot

            if (decidedfullorempty == 0):
                print('Our result: OPEN \n') 
            else:  
                print('Our result: TAKEN \n')

            if (int(lot_data['data']['snapshots'][addup][1]["lotSnapshot"][str(parkingspot[0])]) == decidedfullorempty):
                correctspots = correctspots + 1 #if we were correct then incriment the counter

            saveparkingspace(parkingspacelocation,maskedparkingspace) #save the spot

        for spot in spotColors: #loop through the list of spotColors
            image = boxemup(image, spot[0], spot[1], spot[3], spot[2], spot[4]) #applies the color to each spot

        percentcorrect = (float(correctspots) / len(lot_coords)) * 100   
        sumoverallaverage = sumoverallaverage + percentcorrect
        print ("Percentage of correct spots for the current image:", percentcorrect)
        # ------uses linear interpolation the slowly increment the numwhite threshold --------
        numwhiteratiothreshold =  numwhiteratiothreshold + (numwhiteratiothresholdend - numwhiteratiothresholdstart) / 100.0
        addup = addup + 1
        cv2.imwrite('Output_Images\\'+img_name, image)
    print ("\n Overall Percentage of correctness for the experiment:", sumoverallaverage/nonchangenumImg)
# Out:
# Downloading: Origin_Images\1366030801.jpg Bytes: 230796
#     230796  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  25.089201877934272
# Diff of whitepixels:  38
# Median:  32.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  28.544776119402986
# Diff of whitepixels:  -145
# Median:  76.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  29.136690647482013
# Diff of whitepixels:  -174
# Median:  79.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  23.402247191011234
# Diff of whitepixels:  -125
# Median:  79.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  18.240786240786242
# Diff of whitepixels:  -6
# Median:  84.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  17.201405152224826
# Diff of whitepixels:  -146
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  21.478102189781023
# Diff of whitepixels:  -138
# Median:  90.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  17.52258064516129
# Diff of whitepixels:  -42
# Median:  87.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  9.240174672489083
# Diff of whitepixels:  188
# Median:  71.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  8.562770562770563
# Diff of whitepixels:  172
# Median:  117.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  11.18918918918919
# Diff of whitepixels:  638
# Median:  56.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  32.373056994818654
# Diff of whitepixels:  -96
# Median:  80.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  21.256756756756758
# Diff of whitepixels:  -21
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  20.77625570776256
# Diff of whitepixels:  -65
# Median:  93.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  25.05723905723906
# Diff of whitepixels:  -120
# Median:  104.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  23.524475524475523
# Diff of whitepixels:  -77
# Median:  96.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  18.100746268656717
# Diff of whitepixels:  -89
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  22.119565217391305
# Diff of whitepixels:  -154
# Median:  90.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  14.183266932270916
# Diff of whitepixels:  -24
# Median:  90.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  7.633891213389122
# Diff of whitepixels:  147
# Median:  83.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  13.517241379310345
# Diff of whitepixels:  324
# Median:  68.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  23.18840579710145
# Diff of whitepixels:  -19
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  22.438356164383563
# Diff of whitepixels:  -26
# Median:  93.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  23.055555555555557
# Diff of whitepixels:  -25
# Median:  111.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  22.576
# Diff of whitepixels:  -59
# Median:  96.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  19.275590551181104
# Diff of whitepixels:  -39
# Median:  100.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  19.493392070484582
# Diff of whitepixels:  -12
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  18.447580645161292
# Diff of whitepixels:  -92
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  16.045307443365697
# Diff of whitepixels:  -24
# Median:  99.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  21.773778920308484
# Diff of whitepixels:  -75
# Median:  77.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  25.130111524163567
# Diff of whitepixels:  -191
# Median:  85.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  23.01851851851852
# Diff of whitepixels:  -35
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  25.00485436893204
# Diff of whitepixels:  -87
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  27.123287671232877
# Diff of whitepixels:  -126
# Median:  90.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  24.634920634920636
# Diff of whitepixels:  -113
# Median:  97.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  31.754901960784313
# Diff of whitepixels:  -39
# Median:  101.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  24.993150684931507
# Diff of whitepixels:  -15
# Median:  110.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  29.933823529411764
# Diff of whitepixels:  0
# Median:  90.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  29.218487394957982
# Diff of whitepixels:  -1
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  19.23497267759563
# Diff of whitepixels:  0
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 100.0
# Downloading: Origin_Images\1366031101.jpg Bytes: 223605
#     223605  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  25.661464585834334
# Diff of whitepixels:  19
# Median:  34.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  28.228782287822877
# Diff of whitepixels:  -139
# Median:  74.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  28.859857482185273
# Diff of whitepixels:  -170
# Median:  76.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  22.88791208791209
# Diff of whitepixels:  -115
# Median:  77.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  21.394812680115272
# Diff of whitepixels:  -66
# Median:  81.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  17.241784037558684
# Diff of whitepixels:  -147
# Median:  83.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  10.62274368231047
# Diff of whitepixels:  142
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  14.923076923076923
# Diff of whitepixels:  12
# Median:  85.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  9.728735632183907
# Diff of whitepixels:  165
# Median:  71.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  8.713656387665198
# Diff of whitepixels:  164
# Median:  117.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  12.188420019627085
# Diff of whitepixels:  547
# Median:  57.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  31.396984924623116
# Diff of whitepixels:  -84
# Median:  78.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  21.30474040632054
# Diff of whitepixels:  -22
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  20.72892938496583
# Diff of whitepixels:  -64
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  25.227118644067797
# Diff of whitepixels:  -122
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  23.524475524475523
# Diff of whitepixels:  -77
# Median:  93.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  19.098425196850393
# Diff of whitepixels:  -103
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  21.881720430107528
# Diff of whitepixels:  -151
# Median:  88.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  17.281553398058254
# Diff of whitepixels:  -69
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  7.949891067538126
# Diff of whitepixels:  128
# Median:  83.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.990439770554493
# Diff of whitepixels:  267
# Median:  68.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  16.41025641025641
# Diff of whitepixels:  95
# Median:  60.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  23.316725978647685
# Diff of whitepixels:  -37
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  24.61864406779661
# Diff of whitepixels:  -41
# Median:  111.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  22.850202429149796
# Diff of whitepixels:  -62
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  19.50597609561753
# Diff of whitepixels:  -42
# Median:  101.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  19.323144104803493
# Diff of whitepixels:  -10
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  18.373493975903614
# Diff of whitepixels:  -91
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  20.15447154471545
# Diff of whitepixels:  -87
# Median:  102.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  21.607142857142858
# Diff of whitepixels:  -72
# Median:  78.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  25.130111524163567
# Diff of whitepixels:  -191
# Median:  84.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  23.81226053639847
# Diff of whitepixels:  -44
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  24.884057971014492
# Diff of whitepixels:  -86
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  27.123287671232877
# Diff of whitepixels:  -126
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  24.76595744680851
# Diff of whitepixels:  -114
# Median:  103.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  31.754901960784313
# Diff of whitepixels:  -39
# Median:  106.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  25.34027777777778
# Diff of whitepixels:  -17
# Median:  114.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  29.933823529411764
# Diff of whitepixels:  0
# Median:  97.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  29.218487394957982
# Diff of whitepixels:  -1
# Median:  99.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  19.23497267759563
# Diff of whitepixels:  0
# Median:  103.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 100.0
# Downloading: Origin_Images\1366031401.jpg Bytes: 222757
#     222757  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  26.164014687882496
# Diff of whitepixels:  3
# Median:  38.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  17.0
# Diff of whitepixels:  219
# Median:  41.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  26.644736842105264
# Diff of whitepixels:  -135
# Median:  79.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  24.677725118483412
# Diff of whitepixels:  -148
# Median:  80.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  21.21142857142857
# Diff of whitepixels:  -63
# Median:  81.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  9.993197278911564
# Diff of whitepixels:  162
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  11.145833333333334
# Diff of whitepixels:  116
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  8.890343698854338
# Diff of whitepixels:  259
# Median:  83.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  8.41351888667992
# Diff of whitepixels:  233
# Median:  81.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  10.328981723237598
# Diff of whitepixels:  93
# Median:  104.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  12.964509394572024
# Diff of whitepixels:  486
# Median:  61.0
# Actual result from Json: TAKEN
# Our result: TAKEN
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  15.091787439613526
# Diff of whitepixels:  346
# Median:  51.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  21.45
# Diff of whitepixels:  -25
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  21.162790697674417
# Diff of whitepixels:  -73
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  25.05723905723906
# Diff of whitepixels:  -120
# Median:  103.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  23.690140845070424
# Diff of whitepixels:  -79
# Median:  97.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  19.098425196850393
# Diff of whitepixels:  -103
# Median:  93.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  22.03971119133574
# Diff of whitepixels:  -153
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  17.281553398058254
# Diff of whitepixels:  -69
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  8.856796116504855
# Diff of whitepixels:  81
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.904942965779467
# Diff of whitepixels:  270
# Median:  73.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  22.939068100358423
# Diff of whitepixels:  -16
# Median:  74.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  22.989473684210527
# Diff of whitepixels:  -33
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  24.514767932489452
# Diff of whitepixels:  -40
# Median:  116.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  22.48605577689243
# Diff of whitepixels:  -58
# Median:  104.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  19.662650602409638
# Diff of whitepixels:  -44
# Median:  108.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  19.579646017699115
# Diff of whitepixels:  -13
# Median:  104.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  18.447580645161292
# Diff of whitepixels:  -92
# Median:  105.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  20.31967213114754
# Diff of whitepixels:  -89
# Median:  108.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  21.886304909560724
# Diff of whitepixels:  -77
# Median:  83.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  25.037037037037038
# Diff of whitepixels:  -190
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  23.01851851851852
# Diff of whitepixels:  -35
# Median:  101.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  25.12682926829268
# Diff of whitepixels:  -88
# Median:  104.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  27.310344827586206
# Diff of whitepixels:  -127
# Median:  103.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  24.634920634920636
# Diff of whitepixels:  -113
# Median:  109.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  31.754901960784313
# Diff of whitepixels:  -39
# Median:  113.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  25.34027777777778
# Diff of whitepixels:  -17
# Median:  120.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  16.154761904761905
# Diff of whitepixels:  116
# Median:  96.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  13.743083003952568
# Diff of whitepixels:  133
# Median:  103.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  16.525821596244132
# Diff of whitepixels:  30
# Median:  107.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 95.0
# Downloading: Origin_Images\1366031701.jpg Bytes: 234694
#     234694  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  24.798143851508122
# Diff of whitepixels:  48
# Median:  31.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  15.501519756838906
# Diff of whitepixels:  306
# Median:  33.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  16.735537190082646
# Diff of whitepixels:  135
# Median:  37.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  20.66269841269841
# Diff of whitepixels:  -66
# Median:  72.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  11.36906584992343
# Diff of whitepixels:  240
# Median:  34.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  8.892251815980629
# Diff of whitepixels:  253
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  9.775747508305647
# Diff of whitepixels:  190
# Median:  68.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  8.540880503144654
# Diff of whitepixels:  284
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  7.765137614678899
# Diff of whitepixels:  275
# Median:  73.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  7.927855711422846
# Diff of whitepixels:  209
# Median:  117.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  11.57502329916123
# Diff of whitepixels:  601
# Median:  54.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  15.037304452466907
# Diff of whitepixels:  349
# Median:  42.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  11.7975
# Diff of whitepixels:  335
# Median:  76.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  20.267260579064587
# Diff of whitepixels:  -54
# Median:  87.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  25.227118644067797
# Diff of whitepixels:  -122
# Median:  97.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  23.442508710801395
# Diff of whitepixels:  -76
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  19.023529411764706
# Diff of whitepixels:  -102
# Median:  81.0
# Actual result from Json: OPEN
# Our result: OPEN
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  11.18131868131868
# Diff of whitepixels:  116
# Median:  44.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  10.318840579710145
# Diff of whitepixels:  70
# Median:  48.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  7.830472103004292
# Diff of whitepixels:  135
# Median:  81.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  15.10597302504817
# Diff of whitepixels:  263
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  17.97752808988764
# Diff of whitepixels:  61
# Median:  62.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  22.989473684210527
# Diff of whitepixels:  -33
# Median:  88.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  11.237911025145067
# Diff of whitepixels:  240
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  22.22047244094488
# Diff of whitepixels:  -55
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  19.50597609561753
# Diff of whitepixels:  -42
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  19.493392070484582
# Diff of whitepixels:  -12
# Median:  92.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  18.522267206477732
# Diff of whitepixels:  -93
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  12.979057591623036
# Diff of whitepixels:  49
# Median:  80.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  11.829608938547485
# Diff of whitepixels:  252
# Median:  53.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  14.922737306843267
# Diff of whitepixels:  -7
# Median:  55.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  21.80701754385965
# Diff of whitepixels:  -20
# Median:  89.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  24.070093457943926
# Diff of whitepixels:  -79
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  27.310344827586206
# Diff of whitepixels:  -127
# Median:  88.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  24.898395721925134
# Diff of whitepixels:  -115
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  31.754901960784313
# Diff of whitepixels:  -39
# Median:  99.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  25.697183098591548
# Diff of whitepixels:  -19
# Median:  105.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  12.842271293375394
# Diff of whitepixels:  181
# Median:  76.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  13.424710424710424
# Diff of whitepixels:  139
# Median:  82.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  12.846715328467154
# Diff of whitepixels:  91
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Percentage of correct spots for the current image: 97.5
# Downloading: Origin_Images\1366032001.jpg Bytes: 232734
#     232734  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  26.164014687882496
# Diff of whitepixels:  3
# Median:  33.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  17.114093959731544
# Diff of whitepixels:  213
# Median:  36.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  19.285714285714285
# Diff of whitepixels:  39
# Median:  42.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  10.31089108910891
# Diff of whitepixels:  440
# Median:  56.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  13.233511586452764
# Diff of whitepixels:  148
# Median:  41.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  9.728476821192054
# Diff of whitepixels:  182
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  12.059426229508198
# Diff of whitepixels:  76
# Median:  70.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  9.008291873963516
# Diff of whitepixels:  251
# Median:  77.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  10.633165829145728
# Diff of whitepixels:  128
# Median:  62.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  12.097859327217126
# Diff of whitepixels:  37
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  12.76464542651593
# Diff of whitepixels:  501
# Median:  54.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  15.465346534653465
# Diff of whitepixels:  326
# Median:  44.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  12.053639846743295
# Diff of whitepixels:  318
# Median:  76.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  14.375987361769353
# Diff of whitepixels:  130
# Median:  47.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  22.214925373134328
# Diff of whitepixels:  -82
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  23.442508710801395
# Diff of whitepixels:  -76
# Median:  91.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  19.404
# Diff of whitepixels:  -107
# Median:  83.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  15.775193798449612
# Diff of whitepixels:  -43
# Median:  56.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  11.986531986531986
# Diff of whitepixels:  22
# Median:  60.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  9.261421319796954
# Diff of whitepixels:  63
# Median:  94.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.961832061068701
# Diff of whitepixels:  268
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  17.97752808988764
# Diff of whitepixels:  61
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  20.668769716088327
# Diff of whitepixels:  -1
# Median:  70.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  12.205882352941176
# Diff of whitepixels:  199
# Median:  86.0
# Actual result from Json: TAKEN
# Our result: TAKEN
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  14.288607594936709
# Diff of whitepixels:  86
# Median:  88.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  19.821862348178136
# Diff of whitepixels:  -46
# Median:  99.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  19.407894736842106
# Diff of whitepixels:  -11
# Median:  96.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  13.905775075987842
# Diff of whitepixels:  -11
# Median:  84.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  15.942122186495176
# Diff of whitepixels:  -22
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  12.048364153627311
# Diff of whitepixels:  239
# Median:  62.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  16.85785536159601
# Diff of whitepixels:  -59
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  21.883802816901408
# Diff of whitepixels:  -21
# Median:  99.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  24.183098591549296
# Diff of whitepixels:  -80
# Median:  98.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  25.063291139240505
# Diff of whitepixels:  -114
# Median:  94.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  24.76595744680851
# Diff of whitepixels:  -114
# Median:  101.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  31.754901960784313
# Diff of whitepixels:  -39
# Median:  103.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  26.442028985507246
# Diff of whitepixels:  -23
# Median:  88.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  16.753086419753085
# Diff of whitepixels:  107
# Median:  88.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  15.591928251121077
# Diff of whitepixels:  103
# Median:  93.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  16.923076923076923
# Diff of whitepixels:  25
# Median:  98.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 82.5
# Downloading: Origin_Images\1366032301.jpg Bytes: 239540
#     239540  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  30.064697609001406
# Diff of whitepixels:  -103
# Median:  37.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  17.406143344709896
# Diff of whitepixels:  198
# Median:  39.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  20.1158940397351
# Diff of whitepixels:  13
# Median:  45.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  11.258378378378378
# Diff of whitepixels:  355
# Median:  55.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  16.91116173120729
# Diff of whitepixels:  26
# Median:  46.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  11.621835443037975
# Diff of whitepixels:  59
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  13.847058823529412
# Diff of whitepixels:  13
# Median:  71.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  9.349397590361447
# Diff of whitepixels:  229
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  11.315508021390375
# Diff of whitepixels:  104
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  10.356020942408376
# Diff of whitepixels:  92
# Median:  94.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  13.63336992316136
# Diff of whitepixels:  439
# Median:  56.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  15.67879548306148
# Diff of whitepixels:  315
# Median:  46.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  12.567243675099867
# Diff of whitepixels:  286
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  18.45841784989858
# Diff of whitepixels:  -10
# Median:  52.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  10.138964577656676
# Diff of whitepixels:  317
# Median:  83.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  11.250836120401338
# Diff of whitepixels:  235
# Median:  82.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  10.522776572668112
# Diff of whitepixels:  104
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  15.0
# Diff of whitepixels:  -23
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  12.491228070175438
# Diff of whitepixels:  10
# Median:  70.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  9.28498727735369
# Diff of whitepixels:  62
# Median:  97.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.491682070240296
# Diff of whitepixels:  285
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  17.534246575342465
# Diff of whitepixels:  70
# Median:  69.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  21.272727272727273
# Diff of whitepixels:  -10
# Median:  72.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  12.467811158798284
# Diff of whitepixels:  189
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  15.131367292225201
# Diff of whitepixels:  64
# Median:  87.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  13.268292682926829
# Diff of whitepixels:  76
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  13.053097345132743
# Diff of whitepixels:  100
# Median:  87.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  14.20807453416149
# Diff of whitepixels:  -18
# Median:  89.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  16.97945205479452
# Diff of whitepixels:  -41
# Median:  95.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  12.27536231884058
# Diff of whitepixels:  226
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  17.512953367875646
# Diff of whitepixels:  -74
# Median:  73.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  10.623931623931623
# Diff of whitepixels:  280
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  21.110655737704917
# Diff of whitepixels:  -49
# Median:  95.0
# Actual result from Json: OPEN
# Our result: OPEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  16.431535269709542
# Diff of whitepixels:  -31
# Median:  81.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  9.023255813953488
# Diff of whitepixels:  214
# Median:  105.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  8.825613079019073
# Diff of whitepixels:  226
# Median:  122.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  11.403125
# Diff of whitepixels:  159
# Median:  104.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  21.426315789473684
# Diff of whitepixels:  54
# Median:  101.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  21.596273291925467
# Diff of whitepixels:  41
# Median:  104.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  15.855855855855856
# Diff of whitepixels:  39
# Median:  104.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 70.0
# Downloading: Origin_Images\1366032601.jpg Bytes: 250177
#     250177  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  26.820577164366373
# Diff of whitepixels:  -17
# Median:  30.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  16.293929712460063
# Diff of whitepixels:  258
# Median:  33.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  19.596774193548388
# Diff of whitepixels:  29
# Median:  38.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  10.15009746588694
# Diff of whitepixels:  456
# Median:  52.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  14.332046332046332
# Diff of whitepixels:  105
# Median:  37.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  9.440874035989717
# Diff of whitepixels:  205
# Median:  61.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  11.937119675456389
# Diff of whitepixels:  81
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  8.608557844690967
# Diff of whitepixels:  279
# Median:  74.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  10.659949622166247
# Diff of whitepixels:  127
# Median:  57.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  9.486810551558753
# Diff of whitepixels:  127
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  13.128964059196617
# Diff of whitepixels:  474
# Median:  51.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  14.581096849474912
# Diff of whitepixels:  375
# Median:  40.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  12.193798449612403
# Diff of whitepixels:  309
# Median:  72.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  14.56
# Diff of whitepixels:  122
# Median:  41.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  9.817941952506596
# Diff of whitepixels:  341
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  9.736613603473227
# Diff of whitepixels:  328
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  8.139261744966444
# Diff of whitepixels:  239
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  12.459183673469388
# Diff of whitepixels:  60
# Median:  55.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  10.72289156626506
# Diff of whitepixels:  57
# Median:  58.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  8.64691943127962
# Diff of whitepixels:  91
# Median:  89.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.254545454545454
# Diff of whitepixels:  294
# Median:  58.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  16.75392670157068
# Diff of whitepixels:  87
# Median:  59.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  21.481967213114753
# Diff of whitepixels:  -13
# Median:  61.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  11.832993890020367
# Diff of whitepixels:  214
# Median:  76.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_25
# ...
# Our result: TAKEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  15.529411764705882
# Diff of whitepixels:  -17
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  9.580246913580247
# Diff of whitepixels:  184
# Median:  92.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  8.66042780748663
# Diff of whitepixels:  233
# Median:  110.0
# Actual result from Json: TAKEN
# Our result: TAKEN
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  10.669590643274853
# Diff of whitepixels:  181
# Median:  91.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  16.02755905511811
# Diff of whitepixels:  118
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  15.522321428571429
# Diff of whitepixels:  104
# Median:  82.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  17.170731707317074
# Diff of whitepixels:  22
# Median:  86.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 95.0
# Downloading: Origin_Images\1366032901.jpg Bytes: 254618
#     254618  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  23.20955483170467
# Diff of whitepixels:  107
# Median:  31.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  17.2686230248307
# Diff of whitepixels:  205
# Median:  39.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  19.596774193548388
# Diff of whitepixels:  29
# Median:  44.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  10.847916666666666
# Diff of whitepixels:  390
# Median:  55.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  17.10599078341014
# Diff of whitepixels:  21
# Median:  45.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  10.962686567164178
# Diff of whitepixels:  97
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  11.723107569721115
# Diff of whitepixels:  90
# Median:  70.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  8.80388978930308
# Diff of whitepixels:  265
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  10.907216494845361
# Diff of whitepixels:  118
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  10.779291553133515
# Diff of whitepixels:  77
# Median:  89.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  13.558951965065502
# Diff of whitepixels:  444
# Median:  53.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  13.350427350427351
# Diff of whitepixels:  454
# Median:  46.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  12.353403141361257
# Diff of whitepixels:  299
# Median:  74.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  19.444444444444443
# Diff of whitepixels:  -35
# Median:  53.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  9.856953642384106
# Diff of whitepixels:  338
# Median:  87.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  11.047619047619047
# Diff of whitepixels:  246
# Median:  80.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  10.299363057324841
# Diff of whitepixels:  114
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  14.398584905660377
# Diff of whitepixels:  -6
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  12.233676975945016
# Diff of whitepixels:  16
# Median:  68.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  9.404639175257731
# Diff of whitepixels:  57
# Median:  95.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  14.990439770554493
# Diff of whitepixels:  267
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  17.72853185595568
# Diff of whitepixels:  66
# Median:  64.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  22.593103448275862
# Diff of whitepixels:  -28
# Median:  66.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  12.575757575757576
# Diff of whitepixels:  185
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  16.359420289855073
# Diff of whitepixels:  36
# Median:  84.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  12.91820580474934
# Diff of whitepixels:  86
# Median:  86.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  13.328313253012048
# Diff of whitepixels:  93
# Median:  83.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  13.034188034188034
# Diff of whitepixels:  11
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  14.005649717514125
# Diff of whitepixels:  21
# Median:  91.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  12.293178519593614
# Diff of whitepixels:  225
# Median:  60.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  18.571428571428573
# Diff of whitepixels:  -96
# Median:  65.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  9.912280701754385
# Diff of whitepixels:  322
# Median:  78.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  8.176190476190476
# Diff of whitepixels:  337
# Median:  93.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  16.296296296296298
# Diff of whitepixels:  -29
# Median:  74.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  9.580246913580247
# Diff of whitepixels:  184
# Median:  100.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  8.849726775956285
# Diff of whitepixels:  225
# Median:  116.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  12.24496644295302
# Diff of whitepixels:  137
# Median:  99.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  19.202830188679247
# Diff of whitepixels:  76
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  18.49468085106383
# Diff of whitepixels:  68
# Median:  96.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  19.130434782608695
# Diff of whitepixels:  1
# Median:  94.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 75.0
# Downloading: Origin_Images\1366033202.jpg Bytes: 257819
#     257819  [100.00 None
# Space_#_1
# Number of pixels in image:  21376
# Ratio of white to image:  24.37400228050171
# Diff of whitepixels:  63
# Median:  30.0
# Actual result from Json: TAKEN
# Our result: TAKEN
# Space_#_2
# Number of pixels in image:  15300
# Ratio of white to image:  16.831683168316832
# Diff of whitepixels:  228
# Median:  36.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_3
# Number of pixels in image:  12150
# Ratio of white to image:  20.182724252491695
# Diff of whitepixels:  11
# Median:  41.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_4
# Number of pixels in image:  10414
# Ratio of white to image:  10.626530612244897
# Diff of whitepixels:  410
# Median:  52.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_5
# Number of pixels in image:  7424
# Ratio of white to image:  16.174291938997822
# Diff of whitepixels:  46
# Median:  44.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_6
# Number of pixels in image:  7345
# Ratio of white to image:  12.180762852404644
# Diff of whitepixels:  30
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_7
# Number of pixels in image:  5885
# Ratio of white to image:  11.699801192842942
# Diff of whitepixels:  91
# Median:  67.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_8
# Number of pixels in image:  5432
# Ratio of white to image:  8.56782334384858
# Diff of whitepixels:  282
# Median:  78.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_9
# Number of pixels in image:  4232
# Ratio of white to image:  11.562841530054644
# Diff of whitepixels:  96
# Median:  64.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_10
# Number of pixels in image:  3956
# Ratio of white to image:  11.567251461988304
# Diff of whitepixels:  52
# Median:  85.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_11
# Number of pixels in image:  12420
# Ratio of white to image:  13.861607142857142
# Diff of whitepixels:  424
# Median:  51.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_12
# Number of pixels in image:  12496
# Ratio of white to image:  13.04384133611691
# Diff of whitepixels:  476
# Median:  45.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_13
# Number of pixels in image:  9438
# Ratio of white to image:  12.053639846743295
# Diff of whitepixels:  318
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_14
# Number of pixels in image:  9100
# Ratio of white to image:  17.43295019157088
# Diff of whitepixels:  19
# Median:  50.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_15
# Number of pixels in image:  7442
# Ratio of white to image:  9.728104575163398
# Diff of whitepixels:  348
# Median:  80.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_16
# Number of pixels in image:  6728
# Ratio of white to image:  11.326599326599327
# Diff of whitepixels:  231
# Median:  75.5
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_17
# Number of pixels in image:  4851
# Ratio of white to image:  10.277542372881356
# Diff of whitepixels:  115
# Median:  71.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_18
# Number of pixels in image:  6105
# Ratio of white to image:  13.506637168141593
# Diff of whitepixels:  22
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_19
# Number of pixels in image:  3560
# Ratio of white to image:  11.866666666666667
# Diff of whitepixels:  25
# Median:  64.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_20
# Number of pixels in image:  3649
# Ratio of white to image:  8.750599520383693
# Diff of whitepixels:  86
# Median:  90.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_21
# Number of pixels in image:  7840
# Ratio of white to image:  16.367432150313153
# Diff of whitepixels:  223
# Median:  60.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_22
# Number of pixels in image:  6400
# Ratio of white to image:  17.63085399449036
# Diff of whitepixels:  68
# Median:  61.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_23
# Number of pixels in image:  6552
# Ratio of white to image:  21.91304347826087
# Diff of whitepixels:  -19
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_24
# Number of pixels in image:  5810
# Ratio of white to image:  12.657952069716776
# Diff of whitepixels:  182
# Median:  74.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_25
# Number of pixels in image:  5644
# Ratio of white to image:  16.265129682997117
# Diff of whitepixels:  38
# Median:  79.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_26
# Number of pixels in image:  4896
# Ratio of white to image:  13.909090909090908
# Diff of whitepixels:  59
# Median:  80.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_27
# Number of pixels in image:  4425
# Ratio of white to image:  12.863372093023257
# Diff of whitepixels:  105
# Median:  77.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_28
# Number of pixels in image:  4575
# Ratio of white to image:  14.20807453416149
# Diff of whitepixels:  -18
# Median:  80.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_29
# Number of pixels in image:  4958
# Ratio of white to image:  14.844311377245509
# Diff of whitepixels:  1
# Median:  86.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_30
# Number of pixels in image:  8470
# Ratio of white to image:  12.257597684515195
# Diff of whitepixels:  227
# Median:  57.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_31
# Number of pixels in image:  6760
# Ratio of white to image:  18.52054794520548
# Diff of whitepixels:  -95
# Median:  63.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_32
# Number of pixels in image:  6215
# Ratio of white to image:  10.024193548387096
# Diff of whitepixels:  315
# Median:  75.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_33
# Number of pixels in image:  5151
# Ratio of white to image:  8.389250814332248
# Diff of whitepixels:  321
# Median:  86.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_34
# Number of pixels in image:  3960
# Ratio of white to image:  16.296296296296298
# Diff of whitepixels:  -29
# Median:  70.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_35
# Number of pixels in image:  4656
# Ratio of white to image:  9.906382978723403
# Diff of whitepixels:  168
# Median:  93.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_36
# Number of pixels in image:  3239
# Ratio of white to image:  8.97229916897507
# Diff of whitepixels:  220
# Median:  108.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_37
# Number of pixels in image:  3649
# Ratio of white to image:  12.082781456953642
# Diff of whitepixels:  141
# Median:  93.0
# Actual result from Json: TAKEN
# Our result: TAKEN
#
# Space_#_38
# Number of pixels in image:  4071
# Ratio of white to image:  22.005405405405405
# Diff of whitepixels:  49
# Median:  88.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_39
# Number of pixels in image:  3477
# Ratio of white to image:  19.53370786516854
# Diff of whitepixels:  58
# Median:  89.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Space_#_40
# Number of pixels in image:  3520
# Ratio of white to image:  19.34065934065934
# Diff of whitepixels:  -1
# Median:  87.0
# Actual result from Json: TAKEN
# Our result: OPEN
#
# Percentage of correct spots for the current image: 77.5
#
#  Overall Percentage of correctness for the experiment: 88.05555555555556
